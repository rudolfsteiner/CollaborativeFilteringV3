# %% [markdown]
# # Collaborative filtering explained using Amazon Reviews dataset

# %%
import os
import pandas as pd
import math
import gzip
import numpy as np
import scipy.stats as stats
from scipy.sparse import csc_matrix, csr_matrix
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
from pyspark.mllib.recommendation import ALS, MatrixFactorizationModel, Rating

from sklearn.model_selection import train_test_split as sklearn_train_test_split
import seaborn as sns; sns.set(style="white", color_codes=True)
import warnings
import tensorflow as tf
import TrainingSparseBiasonly as tdb
import TrainingSparseVector as tdv
import TrainingSparseIT as tdit
import TrainingSparseUT as tdut
import TrainingSparseUTDay as tdutday
import TrainingSparseUITDay as tdiutday
import TrainingSparseUIVectorTDay as tdiuvtday
import TrainingSparseUIVectorT_Implicit as tall
import time
from DataProcessing import getBins, train_test_split,PreProcessAmazonDF, convert_csr_to_sparse_tensor_inputs, getMeanDaybyUser, get_df_base_loss
from DataProcessing import getImplicitDF, get_base_loss, parse, getDF, getcsvDF, convert_to_sparse_tensor_inputs, getMeanDay,  patch_with_value, load_from_raw_df, getUserRatedItemCount, getUserRatedItemCountNonUnique
# %matplotlib inline
warnings.filterwarnings("ignore")
# %load_ext autoreload
# %autoreload 2

# %%
#df = getDF('data\\reviews_Patio_Lawn_and_Garden_5.json.gz')
#df = getDF('reviews_Movies_and_TV_10.json.gz')
#df = getDF('data\\reviews_CDs_and_Vinyl_10.json.gz')
#df= getDF('data\\reviews_Electronics_10.json.gz')
df = getDF('data\\reviews_Beauty_10.json.gz')
#df = getDF('data\\reviews_Office_Products_10.json.gz')
#df = getDF("data\\reviews_Home_and_Kitchen_10.json.gz")
#df = getDF("data\\reviews_Video_Games_10.json.gz")

# %%
df = PreProcessAmazonDF(df, bin_count = tdut.Config.item_bin_size)
df.head(5)
# Out:
#                                           reviewText   helpful  overall  \
# 0  I am a devotee to this serum, it does wonders ...    [5, 5]      5.0
# 1  As a woman nearing 50, I need all the help I c...    [2, 2]      5.0
# 2  I've used this regenerating serum for more tha...    [0, 0]      5.0
# 3  I have tried so many products to just be total...  [62, 75]      4.0
# 4  I love Oil of Olay. My primary moisturizer is ...    [1, 1]      1.0
#
#       product                                            summary  \
# 0  B0000CC64W  If I had to choose only one product to take ca...
# 1  B0000CC64W                    Makes my skin lovely and smooth
# 2  B0000CC64W                   Works well at a reasonable price
# 3  B0000CC64W                              This does work ladies
# 4  B0000CC64W        Did not like the feel/texture of this serum
#
#        reviewerID ReviewTime                          reviewerName  ReviewDay  \
# 0   A6VPK7X53QNAQ 2009-06-18  AmazonDiva "Keep Calm and Carry On."       1527
# 1  A3CHMHGSJSQ02J 2013-01-18                          Anon. A. Non       2837
# 2  A1V1EP514B5H7Y 2011-11-29                                asiana       2421
# 3  A1X2LENOF84LCQ 2005-04-13                                 D "D"          0
# 4  A2PATWWZAXHQYA 2013-12-21                        Farnoosh Brock       3174
#
#    ITBin  userID  itemID  TDayCat
# 0     26    1041       0      384
# 1     49     808       0     1407
# 2     42     279       0     1003
# 3      0     301       0        0
# 4     55     582       0     1744

# %%
df = df.drop("reviewerName", 1)
df = df.drop("reviewText",1)
df = df.drop("summary", 1)

# %%
df.head(10)
# Out:
#     helpful  overall     product      reviewerID ReviewTime  ReviewDay  ITBin  \
# 0    [5, 5]      5.0  B0000CC64W   A6VPK7X53QNAQ 2009-06-18       1527     26
# 1    [2, 2]      5.0  B0000CC64W  A3CHMHGSJSQ02J 2013-01-18       2837     49
# 2    [0, 0]      5.0  B0000CC64W  A1V1EP514B5H7Y 2011-11-29       2421     42
# 3  [62, 75]      4.0  B0000CC64W  A1X2LENOF84LCQ 2005-04-13          0      0
# 4    [1, 1]      1.0  B0000CC64W  A2PATWWZAXHQYA 2013-12-21       3174     55
# 5  [12, 13]      5.0  B0000CC64W  A3IOCPLIMYDBCD 2009-07-04       1543     27
# 6    [1, 2]      3.0  B0000CC64W   A5A3C6XVDYUND 2013-02-18       2868     50
# 7    [6, 7]      4.0  B0000CC64W  A3V6Z4RCDGRC44 2007-07-01        809     14
# 8    [0, 0]      4.0  B0000CC64W  A2WW57XX2UVLM6 2013-11-22       3145     55
# 9    [2, 3]      5.0  B0000CC64W  A3M7R4PD0FEPUB 2009-09-28       1629     28
#
#    userID  itemID  TDayCat
# 0    1041       0      384
# 1     808       0     1407
# 2     279       0     1003
# 3     301       0        0
# 4     582       0     1744
# 5     879       0      399
# 6    1027       0     1438
# 7    1003       0        1
# 8     662       0     1715
# 9     920       0      439

# %%
train_df, test_df = sklearn_train_test_split(df, test_size=0.2, random_state = 42)
train_df, dev_df = sklearn_train_test_split(train_df, test_size=0.25, random_state = 38)

# %%
implicit_train_df = getImplicitDF(train_df)

# %%
num_user = df.groupby("userID")["userID"].unique().count()
num_item = df.groupby("itemID")["itemID"].unique().count()
print(num_user, num_item)
# Out:
# 1340 733

# %%
average_rank = df["overall"].mean()

fig = plt.figure(figsize=(10,10))

mean_rating_of_user = df.groupby('reviewerID').apply(lambda x: x['overall'].mean())
ax = fig.add_subplot(322)
ax.hist(mean_rating_of_user)
ax.set_xlabel('mean rating given by each user', fontsize=15)

plt.tight_layout()
plt.show()

# %%
average_rank = df["overall"].mean()
fig = plt.figure(figsize=(10,10))

# mean ratings from each user
mean_rating_of_item = df.groupby('product').apply(lambda x: x['overall'].mean())
ax = fig.add_subplot(322)
ax.hist(mean_rating_of_user)
ax.set_xlabel('mean rating by each product', fontsize=15)

plt.tight_layout()
plt.show()

# %%
def train_by_df(from_model, train_df, dev_df, test_df, num_user, num_item, debug = True, implicit_df = None):
    print (80 * "=")
    print ("INITIALIZING")
    print( 80 * "=")
    config = from_model.Config()
    config.n_items = num_item 
    config.n_users = num_user
    config.maxday_cat_code = max(train_df["TDayCat"].values)
    
    if not os.path.exists('data\\weights\\'):
        os.makedirs('.\\data\\weights\\')

    with tf.Graph().as_default():
        print ("Building model...",)
        start = time.time()
        model = from_model.RecommandationModel(config) 
        

        init = tf.global_variables_initializer()

        saver = None if debug else tf.train.Saver()

        with tf.Session() as session:
            #recommand.session = session
            session.run(init)

            print( 80 * "=")
            print( "TRAINING")
            print( 80 * "=")
            model.fit(session, saver, train_df, dev_df) #, implicit_df)
            print("Done!")
            print ("took {:.2f} seconds\n".format(time.time() - start))
            
            if not debug:
                print (80 * "=")
                print ("TESTING")
                print( 80 * "=")
                print ("Restoring the best model weights found on the dev set")
                #saver.restore(session, model.config.weight_filename)
                print ("Final evaluation on test set",)
                mean_rank = train_df["overall"].mean() #global rank mean
        
                mean_u_day = getMeanDaybyUser(train_df)
                test_loss = model.run_epoch(session, train_df, mean_rank, mean_u_day, test_df) 
                
                print ("- test l2 loss: {:.5f}", test_loss)

                print ("Done!")
                
                return test_loss

# %%
def train_by_df_timeVCDplus(from_model, train_df, dev_df, test_df, num_user, num_item, debug = True, implicit_df = None):
    print (80 * "=")
    print ("INITIALIZING")
    print( 80 * "=")
    config = from_model.Config()
    config.n_items = num_item 
    config.n_users = num_user
    config.maxday_cat_code = max(train_df["TDayCat"].values)
    
    if not os.path.exists('data\\weights\\'):
        os.makedirs('.\\data\\weights\\')

    with tf.Graph().as_default():
        print ("Building model...",)
        start = time.time()
        model = from_model.RecommandationModel(config) 
        

        init = tf.global_variables_initializer()

        saver = None if debug else tf.train.Saver()

        with tf.Session() as session:
            #recommand.session = session
            session.run(init)

            print( 80 * "=")
            print( "TRAINING")
            print( 80 * "=")
            model.fit(session, saver, train_df, dev_df, implicit_df)
            print("Done!")
            print ("took {:.2f} seconds\n".format(time.time() - start))
            
            if not debug:
                print (80 * "=")
                print ("TESTING")
                print( 80 * "=")
                print ("Restoring the best model weights found on the dev set")
                #saver.restore(session, model.config.weight_filename)
                print ("Final evaluation on test set",)
                mean_rank = train_df["overall"].mean() #global rank mean
        
                mean_u_day = getMeanDaybyUser(train_df)
                test_loss = model.run_epoch(session, train_df, mean_rank, mean_u_day, test_df, implicit_df) 
                
                print ("- test l2 loss: {:.5f}", test_loss)

                print ("Done!")
                
                return test_loss

# %%
loss_dict={}
loss_dict["Base"] = get_df_base_loss(train_df, dev_df, test_df)[2]
# Out:
# mean is:  4.16275031832

# %% [markdown]
# This is the whole matrix factorization model(timeVCD++) for recommender system:
# \begin{align}
# \hat{r}_{ui} = \mu + b_i(t_{ui}) + b_u(t_{ui}) + q_i^T\left(p_u(t_{ui}) + |R(u)|^{-\frac{1}{2}}\sum_{j \in R(u)}y_j\right) \\
# p_{uk}(t) = p_{uk} + \alpha_{uk}{\cdot}dev_u(t) + p_{uk,t}  \\
# b_i(t_{ui}) = b_i + b_{i,Bin(t)}\\
# b_u(t_{ui}) = b_u + \alpha_{u}{\cdot}dev_u(t) + b_{u,t}
# \end{align}

# %%
loss_dict["TALL"] = train_by_df_timeVCDplus(tall, train_df, dev_df, test_df, num_user, num_item, debug = False, implicit_df = implicit_train_df )
# Out:
# ================================================================================
# INITIALIZING
# ================================================================================
# Building model...
# ================================================================================
# TRAINING
# ================================================================================
# Epoch 1 out of 30
# Evaluating on dev set
# current DEV loss =  0.975156420886
# new best dev loss!: 0.975156420886
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 2 out of 30
# Evaluating on dev set
# current DEV loss =  0.958512839695
# new best dev loss!: 0.958512839695
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 3 out of 30
# Evaluating on dev set
# current DEV loss =  0.943484745269
# new best dev loss!: 0.943484745269
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 4 out of 30
# Evaluating on dev set
# current DEV loss =  0.929429715157
# new best dev loss!: 0.929429715157
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 5 out of 30
# Evaluating on dev set
# current DEV loss =  0.91613379044
# new best dev loss!: 0.91613379044
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 6 out of 30
# Evaluating on dev set
# current DEV loss =  0.903390973257
# new best dev loss!: 0.903390973257
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 7 out of 30
# Evaluating on dev set
# current DEV loss =  0.891287147924
# new best dev loss!: 0.891287147924
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 8 out of 30
# Evaluating on dev set
# current DEV loss =  0.879936364806
# new best dev loss!: 0.879936364806
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 9 out of 30
# Evaluating on dev set
# current DEV loss =  0.869458566025
# new best dev loss!: 0.869458566025
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 10 out of 30
# Evaluating on dev set
# current DEV loss =  0.860003388337
# new best dev loss!: 0.860003388337
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 11 out of 30
# Evaluating on dev set
# current DEV loss =  0.85159329977
# new best dev loss!: 0.85159329977
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 12 out of 30
# Evaluating on dev set
# current DEV loss =  0.844135911304
# new best dev loss!: 0.844135911304
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 13 out of 30
# Evaluating on dev set
# current DEV loss =  0.837599796318
# new best dev loss!: 0.837599796318
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 14 out of 30
# Evaluating on dev set
# current DEV loss =  0.831902749545
# new best dev loss!: 0.831902749545
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 15 out of 30
# Evaluating on dev set
# current DEV loss =  0.826868001015
# new best dev loss!: 0.826868001015
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 16 out of 30
# Evaluating on dev set
# current DEV loss =  0.822170349925
# new best dev loss!: 0.822170349925
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 17 out of 30
# Evaluating on dev set
# current DEV loss =  0.818152481223
# new best dev loss!: 0.818152481223
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 18 out of 30
# Evaluating on dev set
# current DEV loss =  0.814440009798
# new best dev loss!: 0.814440009798
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 19 out of 30
# Evaluating on dev set
# current DEV loss =  0.811194448806
# new best dev loss!: 0.811194448806
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 20 out of 30
# Evaluating on dev set
# current DEV loss =  0.808050866699
# new best dev loss!: 0.808050866699
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 21 out of 30
# Evaluating on dev set
# current DEV loss =  0.805367114238
# new best dev loss!: 0.805367114238
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 22 out of 30
# Evaluating on dev set
# current DEV loss =  0.803031823942
# new best dev loss!: 0.803031823942
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 23 out of 30
# Evaluating on dev set
# current DEV loss =  0.80094177057
# new best dev loss!: 0.80094177057
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 24 out of 30
# Evaluating on dev set
# current DEV loss =  0.799193674982
# new best dev loss!: 0.799193674982
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 25 out of 30
# Evaluating on dev set
# current DEV loss =  0.797756539622
# new best dev loss!: 0.797756539622
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 26 out of 30
# Evaluating on dev set
# current DEV loss =  0.79642156051
# new best dev loss!: 0.79642156051
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 27 out of 30
# Evaluating on dev set
# current DEV loss =  0.795540174651
# new best dev loss!: 0.795540174651
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 28 out of 30
# Evaluating on dev set
# current DEV loss =  0.794855456466
# new best dev loss!: 0.794855456466
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 29 out of 30
# Evaluating on dev set
# current DEV loss =  0.794287091935
# new best dev loss!: 0.794287091935
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Epoch 30 out of 30
# Evaluating on dev set
# current DEV loss =  0.793894581736
# new best dev loss!: 0.793894581736
# New best dev UAS! data\weights\recommanding_with_IU_time_drifting.weight
#
# Done!
# took 48.26 seconds
#
# ================================================================================
# TESTING
# ================================================================================
# Restoring the best model weights found on the dev set
# Final evaluation on test set
# Evaluating on dev set
# - test l2 loss: {:.5f} 0.732678866753
# Done!

# %%
loss_dict["VTDay"] = train_by_df(tdiuvtday, train_df, dev_df, test_df, num_user, num_item, debug = False)
# Out:
# ================================================================================
# INITIALIZING
# ================================================================================
# Building model...
# ================================================================================
# TRAINING
# ================================================================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-fb6d71d398a9> in <module>()
# ----> 1 loss_dict["VTDay"] = train_by_df(tdiuvtday, train_df, dev_df, test_df, num_user, num_item, debug = False)
#
# <ipython-input-11-1034cffb9ca5> in train_by_df(from_model, train_df, dev_df, test_df, num_user, num_item, debug, implicit_df)
#      28             print( "TRAINING")
#      29             print( 80 * "=")
# ---> 30             model.fit(session, saver, train_df, dev_df, implicit_df)
#      31             print("Done!")
#      32             print ("took {:.2f} seconds\n".format(time.time() - start))
#
# TypeError: fit() takes 5 positional arguments but 6 were given

# %%
loss_dict["IUDay"] = train_by_df(tdiutday, train_df, dev_df, test_df, num_user, num_item, debug = False)

# %%
loss_dict["UserDay"] = train_by_df(tdutday, train_df, dev_df, test_df, num_user, num_item, debug = False)

# %%
loss_dict["UserTime"] = train_by_df(tdut, train_df, dev_df, test_df, num_user, num_item, debug = False)

# %%
loss_dict["ItemTime"] = train_by_df(tdit, train_df, dev_df, test_df, num_user, num_item, debug = False)

# %%
loss_dict["Vector"] = train_by_df(tdv, train_df, dev_df, test_df, num_user, num_item, debug = False)

# %%
loss_dict["Biasonly"] = train_by_df(tdb, train_df, dev_df, test_df, num_user, num_item, debug = False)

# %%
N = len(loss_dict.values())
x = list(loss_dict.values()) 

ind = np.arange(N)  
width = 0.35       # the width of the bars

fig, ax = plt.subplots(figsize=(9, 7))
g1 = ax.bar(ind, x, width, color='b')
g2 = ax.plot(x, 'r')

# add some text for labels, title and axes ticks
ax.set_ylabel('L2 Loss', fontsize=15)
ax.set_title('Model Comparison', fontsize=15)
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(list(loss_dict.keys())) 
ax.tick_params(labelsize=10)
ax.set_ylim([0.65, max(x) + 0.1])

# %%
print(loss_dict)
